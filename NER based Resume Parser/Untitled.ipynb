# %% [markdown]
# # Reference:
# - https://www.youtube.com/watch?v=WpaioLNsoGI

# %% [markdown]
# **STEPS:**
# 1. Downloading the base [config file](https://spacy.io/usage/training) after selecting the appropriate options.
#     <div>
#     <img src="attachment:image.png" width="400"/>
#     </div>
#
# 2.
